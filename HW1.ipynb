# %% [markdown]
# <a href="https://colab.research.google.com/github/nirada-git/nirada-git/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ณิรดา อนุนิวัฒน์

# %%
print('ID673020252-4')
# Out:
# ID673020252-4
